# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
kw = pd.read_csv('지역별_관광지_검색순위.csv')

# %%
kw
# Out:
#       순위         관광지명  광역시/도 시/군/구                도로명주소 중분류 카테고리     소분류 카테고리  \
# 0      1  신세계백화점센텀시티점  부산광역시  해운대구   부산 해운대구 센텀남대로 35-0       쇼핑          백화점
# 1      2    김해공항국내선청사  부산광역시   강서구   부산 강서구 공항진입로 108-0     기타관광         교통시설
# 2      3    롯데백화점부산본점  부산광역시  부산진구   부산 부산진구 가야대로 772-0       쇼핑          백화점
# 3      4       김해국제공항  부산광역시   강서구   부산 강서구 공항진입로 108-0     기타관광         교통시설
# 4      5      광안리해수욕장  부산광역시   수영구   부산 수영구 광안해변로 219-0     자연관광  자연경관(하천/해양)
# ..   ...          ...    ...   ...                  ...      ...          ...
# 995  496      메가박스해운대  부산광역시  해운대구   부산 해운대구 해운대로 813-0     문화관광         공연시설
# 996  496       광안종합시장  부산광역시   수영구  부산 수영구 무학로49번길 71-0       쇼핑           시장
# 997  498      메가박스부산대  부산광역시   금정구  부산 금정구 장전로12번길 55-0     문화관광         공연시설
# 998  499      구포무장애숲길  부산광역시    북구                부산 북구    레저스포츠      기타레저스포츠
# 999  500       비콘그라운드  부산광역시   수영구     부산 수영구 망미번영로 0-0     문화관광      기타문화관광지
#
#         검색건수
# 0    559,499
# ...

# %%
kw.sort_values('검색건수')
# Out:
#       순위             관광지명  광역시/도 시/군/구                   도로명주소 중분류 카테고리  \
# 333  225            부산박물관  부산광역시    남구        부산 남구 유엔평화로 63-0     문화관광
# 332  109         어라우즈로스터리  부산광역시   강서구     부산 강서구 르노삼성대로 630-0       음식
# 331  108       맥도날드해운대DT점  부산광역시  해운대구  부산 해운대구 해운대로570번길 51-0       음식
# 330  224  트레이더스 홀세일 클럽연산점  부산광역시   연제구       부산 연제구 좌수영로 241-0       쇼핑
# 329  107           세연정동래점  부산광역시   동래구       부산 동래구 충렬대로 149-0       음식
# ..   ...              ...    ...   ...                     ...      ...
# 334  110      맥도날드부산기장DT점  부산광역시   기장군       부산 기장군 기장대로 500-0       음식
# 26    26           이마트문현점  부산광역시    남구     부산 남구 전포대로91번길 47-0       쇼핑
# 25    25          이마트해운대점  부산광역시  해운대구     부산 해운대구 좌동순환로 511-0       쇼핑
# 24    24            자갈치시장  부산광역시    중구       부산 중구 자갈치해안로 52-0       쇼핑
# 23    23      이마트트레이더스명지점  부산광역시   강서구     부산 강서구 명지국제6로 168-0       쇼핑
#
#     소분류 카테고리    검색건수
# 333     전시시설  10,021
# 332    카페/찻집  10,043
# 331     간이음식  10,109
# ...
